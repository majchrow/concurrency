# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results=pd.read_csv("result.csv", index_col='ThreadNumber')

# %%
results.head()
# Out:
#                     Time
# ThreadNumber
# 1             6920636472
# 2             3927076204
# 3             2187919399
# 4             2301161438
# 5             1720659762

# %%
results.plot()

# %%
results[25:].plot()

# %%
results[5:15].plot()
